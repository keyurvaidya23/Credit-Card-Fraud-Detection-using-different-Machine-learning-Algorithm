# %%
  import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['ggplot'])
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv("/content/drive/MyDrive/CS 677/project/Credit card fraud detection/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.describe(include="all").T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
# null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# showing if there duplicated values or not
df.drop(columns='Class',axis=1).duplicated().sum()
# Out:
# 1081

# %% [markdown]
# ##Data Wrangling

# %%
df['Class'].value_counts() #imbalance
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
scaler=StandardScaler()
# Reshaping the 'Time' and 'Amount' columns
scaled_time = scaler.fit_transform(df['Time'].values.reshape(-1, 1))
scaled_amount = scaler.fit_transform(df['Amount'].values.reshape(-1, 1))

# Creating a new DataFrame with scaled values
scaled_df = pd.DataFrame({
    'Scaled_Time': scaled_time.flatten(),
    'Scaled_Amount': scaled_amount.flatten()
})

# Display the first few rows of the scaled DataFrame
print(scaled_df.head())
# Out:
#    Scaled_Time  Scaled_Amount
# 0    -1.996583       0.244964
# 1    -1.996583      -0.342475
# 2    -1.996562       1.160686
# 3    -1.996562       0.140534
# 4    -1.996541      -0.073403

# %% [markdown]
# ##Exploratory Data Analysis (EDA)

# %%
df['Time'].plot()
plt.show()

# %%
df.drop('Class',axis=1).corrwith(df.Class).plot(kind='bar',grid=True,figsize=(10,6),title="Correlation with Class ")
# Out:
# <Axes: title={'center': 'Correlation with Class '}>

# %%
plt.pie(df['Class'].value_counts().values,autopct='%1.1f%%',labels=df['Class'].value_counts().index,shadow=True)
plt.axis('equal')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# ##Splitting of data

# %%
x=df.drop(columns='Class',axis=1)
y=df['Class']

# %%
# Here, I'm using 70% of the data for training and 30% for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=45)

# %% [markdown]
# ##Model

# %% [markdown]
# ##Random Forest

# %%
rf=RandomForestClassifier()
model1=rf.fit(x_train,y_train)
y_pred=model1.predict(x_test)


print(f'classification report :{classification_report(y_test,y_pred)}')
print('*************************************')
print(f'confusion matrix :{confusion_matrix(y_test,y_pred)}')
print('*************************************')
print(f'accuracy score :{accuracy_score(y_test,y_pred)}')
# Out:
# classification report :              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85278
#            1       0.94      0.82      0.87       165
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.91      0.94     85443
# weighted avg       1.00      1.00      1.00     85443
#
# *************************************
# confusion matrix :[[85269     9]
#  [   30   135]]
# *************************************
# accuracy score :0.9995435553526912

# %% [markdown]
# ##Logistic Regression

# %%
lr=LogisticRegression(max_iter=1000)
model2=lr.fit(x_train,y_train)
y_pred2=model2.predict(x_test)


print(f'classification report :{classification_report(y_test,y_pred2)}')
print('*************************************')
print(f'confusion matrix :{confusion_matrix(y_test,y_pred2)}')
print('*************************************')
print(f'accuracy score :{accuracy_score(y_test,y_pred2)}')
# Out:
# classification report :              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85278
#            1       0.88      0.64      0.74       165
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.82      0.87     85443
# weighted avg       1.00      1.00      1.00     85443
#
# *************************************
# confusion matrix :[[85263    15]
#  [   59   106]]
# *************************************
# accuracy score :0.999133925541004

# %% [markdown]
# ##Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=45)

model_3 = dt.fit(x_train, y_train)

y_pred3 = model_3.predict(x_test)

print(f'Classification Report:\n{classification_report(y_test, y_pred3)}')
print('*************************************')

print(f'Confusion Matrix:\n{confusion_matrix(y_test, y_pred3)}')
print('*************************************')

print(f'Accuracy Score: {accuracy_score(y_test, y_pred3)}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85278
#            1       0.76      0.84      0.80       165
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.92      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
#
# *************************************
# Confusion Matrix:
# [[85234    44]
#  [   26   139]]
# *************************************
# Accuracy Score: 0.9991807403766253

# %% [markdown]
# ##Comparsion of algorithm

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming the predictions and true labels are stored in the variables as follows:
# y_pred (Random Forest), y_pred2 (Logistic Regression), y_pred3 (Decision Tree)

# Extracting metrics for each model
# Placeholder variables for the predictions - to be replaced with actual predictions
y_pred_rf = y_pred   # Random Forest predictions
y_pred_lr = y_pred2  # Logistic Regression predictions
y_pred_dt = y_pred3  # Decision Tree predictions

# Calculating metrics for Random Forest
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)

# Calculating metrics for Logistic Regression
accuracy_lr = accuracy_score(y_test, y_pred_lr)
precision_lr = precision_score(y_test, y_pred_lr)
recall_lr = recall_score(y_test, y_pred_lr)
f1_lr = f1_score(y_test, y_pred_lr)

# Calculating metrics for Decision Tree
accuracy_dt = accuracy_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt)
recall_dt = recall_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt)

# Preparing data for bar plot
models = ['Random Forest', 'Logistic Regression', 'Decision Tree']
accuracies = [accuracy_rf, accuracy_lr, accuracy_dt]
precisions = [precision_rf, precision_lr, precision_dt]
recalls = [recall_rf, recall_lr, recall_dt]
f1_scores = [f1_rf, f1_lr, f1_dt]

# Plotting
plt.figure(figsize=(12, 6))

# Bar width
barWidth = 0.15
# Position of bars on x-axis
r1 = np.arange(len(models))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

plt.bar(r1, accuracies, color='blue', width=barWidth, edgecolor='grey', label='Accuracy')
plt.bar(r2, precisions, color='red', width=barWidth, edgecolor='grey', label='Precision')
plt.bar(r3, recalls, color='green', width=barWidth, edgecolor='grey', label='Recall')
plt.bar(r4, f1_scores, color='orange', width=barWidth, edgecolor='grey', label='F1 Score')

plt.xlabel('Model', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(accuracies))], models)
plt.ylabel('Score')
plt.title('Comparison of Machine Learning Models')

plt.legend()
plt.show()
